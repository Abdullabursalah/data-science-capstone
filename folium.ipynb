# %%
import folium
import pandas as pd
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon
import requests
import io

# %%
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'

# Fetch the CSV content from the URL
response = requests.get(URL)
response.raise_for_status()  # Ensure the request was successful

# Read the CSV content into a pandas DataFrame
csv_data = io.StringIO(response.text)
df = pd.read_csv(csv_data)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df.shape
# Out:
# (4, 3)

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd98a957cb9cd73dcade1e3a322ea31c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd98a957cb9cd73dcade1e3a322ea31c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd98a957cb9cd73dcade1e3a322ea31c = L.map(
#                 &quot;map_bd98a957cb9cd73dcade1e3a322ea31c&quot;,
#                 {
#                     center: [28.56230197, -80.57735648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e31beb769c97c2cc59f5a27af2acb151 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd98a957cb9cd73dcade1e3a322ea31c);
#
#
#             var circle_8169e5a16384a15b8b50c5534a8a16e1 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd98a957cb9cd73dcade1e3a322ea31c);
#
#
#         var popup_bf2fa83323ae1309a687880cfadb19a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6429ba2c330929e0b799dcec04f054a3 = $(`&lt;div id=&quot;html_6429ba2c330929e0b799dcec04f054a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#             popup_bf2fa83323ae1309a687880cfadb19a0.setContent(html_6429ba2c330929e0b799dcec04f054a3);
#
#
#         circle_8169e5a16384a15b8b50c5534a8a16e1.bindPopup(popup_bf2fa83323ae1309a687880cfadb19a0)
#         ;
#
#
#
#
#             var marker_2feec363cf9f98165ef8a2c5b814d407 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_bd98a957cb9cd73dcade1e3a322ea31c);
#
#
#             var div_icon_fea65272a7c8d4b8ac52fc89dc8e8a18 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_2feec363cf9f98165ef8a2c5b814d407.setIcon(div_icon_fea65272a7c8d4b8ac52fc89dc8e8a18);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Initial the map
site_map = folium.Map(location=selected_row, zoom_start=5)
# site_map
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label

# %%
selected_row = launch_sites_df.iloc[0, [1, 2]]
selected_row
# Out:
# Lat     28.562302
# Long   -80.577356
# Name: 0, dtype: object

# %%
# # Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
# circle = folium.Circle(selected_row, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# # Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
# marker = folium.map.Marker(
#     selected_row,
#     # Create an icon as a text label
#     icon=DivIcon(
#         icon_size=(20,20),
#         icon_anchor=(0,0),
#         html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
#         )
#     )
# site_map.add_child(circle)
# site_map.add_child(marker)

# %%
# Create a map centered at the first launch site
launch_map = folium.Map(location=[launch_sites_df["Lat"].mean(), launch_sites_df["Long"].mean()], zoom_start=5)

# Add markers for each launch site
for _, row in launch_sites_df.iterrows():
    location = (row["Lat"], row["Long"])
    popup_text = f"Launch Site: {row['Launch Site']}"
    
   
    
    # Add a circle marker
    folium.CircleMarker(
        location,
        radius=10,
        color='#d35400',
        fill=True,
        # fill_color=color,
        popup=folium.Popup(popup_text, max_width=300),
    ).add_to(launch_map)

# Display the map
# launch_map

# %%
# Create a map centered at the average latitude and longitude
launch_map = folium.Map(
    location=[launch_sites_df["Lat"].mean(), launch_sites_df["Long"].mean()],
    zoom_start=5,
)

# Add Circle and Marker for each launch site
for _, row in launch_sites_df.iterrows():
    location = (row["Lat"], row["Long"])
    popup_text = f"Launch Site: {row['Launch Site']}"
    
    # Add a Circle
    folium.Circle(
        location=location,
        radius=1000,  # Radius in meters
        color="blue",  # Uniform color
        fill=True,
        fill_color="blue",
        popup=folium.Popup(popup_text, max_width=300),
    ).add_to(launch_map)
    
    # Add a Marker
    folium.Marker(
        location=location,
        icon=folium.Icon(color="blue", icon="info-sign"),
        popup=folium.Popup(popup_text, max_width=300),
    ).add_to(launch_map)

# Display the map
# launch_map

# %%
import folium
import pandas as pd
from folium import DivIcon

# Sample DataFrame (replace with your actual data)
data = {
    "Launch Site": ["Site A", "Site B", "Site C"],
    "Lat": [28.5623, 34.6325, 25.9968],
    "Long": [-80.5774, -120.6108, -97.4887],
}
launch_sites_df = pd.DataFrame(data)

# Create a map centered at the average latitude and longitude
launch_map = folium.Map(
    location=[launch_sites_df["Lat"].mean(), launch_sites_df["Long"].mean()],
    zoom_start=5,
)

# Add Circle and Marker for each launch site with custom label
for _, row in launch_sites_df.iterrows():
    location = (row["Lat"], row["Long"])
    launch_site_name = row["Launch Site"]
    
    # Add a Circle marker
    folium.CircleMarker(
        location=location,
        radius=10,
        color="#d35400",
        fill=True,
        fill_color="#d35400",
        popup=folium.Popup(f"Launch Site: {launch_site_name}", max_width=300),
    ).add_to(launch_map)
    
    # Add a custom label using DivIcon
    folium.map.Marker(
        location=location,
        icon=DivIcon(
            icon_size=(150, 36),  # Adjust size if needed
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 12px; color: #d35400;"><b>{launch_site_name}</b></div>',
        ),
    ).add_to(launch_map)

# Display the map
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_709d23ed89cb4fce998c9e3426a11884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_709d23ed89cb4fce998c9e3426a11884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_709d23ed89cb4fce998c9e3426a11884 = L.map(
#                 &quot;map_709d23ed89cb4fce998c9e3426a11884&quot;,
#                 {
#                     center: [29.73053333333333, -99.55896666666666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01219c8e7f1b28e06db4d92140ecc2b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_709d23ed89cb4fce998c9e3426a11884);
#
#
#             var circle_marker_7eb59f6e23a281bad9f3c48c4668582f = L.circleMarker(
#                 [28.5623, -80.5774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_709d23ed89cb4fce998c9e3426a11884);
#
#
#         var popup_df09b760e8f2cca369ff4bf34a70bcf5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_b737f4ee80ebc7ac12f04fadef395070 = $(`&lt;div id=&quot;html_b737f4ee80ebc7ac12f04fadef395070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: Site A&lt;/div&gt;`)[0];
#             popup_df09b760e8f2cca369ff4bf34a70bcf5.setContent(html_b737f4ee80ebc7ac12f04fadef395070);
#
#
#         circle_marker_7eb59f6e23a281bad9f3c48c4668582f.bindPopup(popup_df09b760e8f2cca369ff4bf34a70bcf5)
#         ;
#
#
#
#
#             var marker_5f6a5d8881b0ada91a2c496b0cd1676a = L.marker(
#                 [28.5623, -80.5774],
#                 {}
#             ).addTo(map_709d23ed89cb4fce998c9e3426a11884);
#
#
#             var div_icon_0b7f76c064e94e9e019be432d932af2a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: #d35400;\&quot;\u003e\u003cb\u003eSite A\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_5f6a5d8881b0ada91a2c496b0cd1676a.setIcon(div_icon_0b7f76c064e94e9e019be432d932af2a);
#
#
#             var circle_marker_eb89412bb92bcd707d4d58174e51e5e8 = L.circleMarker(
#                 [34.6325, -120.6108],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_709d23ed89cb4fce998c9e3426a11884);
#
#
#         var popup_9d58c984037f4244a6f4a18084bb04a0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_1a4fd7251611b4c9520787dca1a91989 = $(`&lt;div id=&quot;html_1a4fd7251611b4c9520787dca1a91989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: Site B&lt;/div&gt;`)[0];
#             popup_9d58c984037f4244a6f4a18084bb04a0.setContent(html_1a4fd7251611b4c9520787dca1a91989);
#
#
#         circle_marker_eb89412bb92bcd707d4d58174e51e5e8.bindPopup(popup_9d58c984037f4244a6f4a18084bb04a0)
#         ;
#
#
#
#
#             var marker_0e017afee11c32da9686ff436324ba2b = L.marker(
#                 [34.6325, -120.6108],
#                 {}
#             ).addTo(map_709d23ed89cb4fce998c9e3426a11884);
#
#
#             var div_icon_40d577783b6e5ef593efe0154ad0e3f7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: #d35400;\&quot;\u003e\u003cb\u003eSite B\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_0e017afee11c32da9686ff436324ba2b.setIcon(div_icon_40d577783b6e5ef593efe0154ad0e3f7);
#
#
#             var circle_marker_5d85bd649dc7afe1c6618f7df02e54e0 = L.circleMarker(
#                 [25.9968, -97.4887],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quo

# %%
import folium
from folium import DivIcon

# Define the coordinates and names of the launch sites
launch_sites = [
    {"name": "CCAFS LC-40", "lat": 28.562302, "long": -80.577356},
    {"name": "CCAFS SLC-40", "lat": 28.563197, "long": -80.576820},
    {"name": "KSC LC-39A", "lat": 28.573255, "long": -80.646895},
    {"name": "VAFB SLC-4E", "lat": 34.632834, "long": -120.610745},
]

# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[sum([site["lat"] for site in launch_sites]) / len(launch_sites),
             sum([site["long"] for site in launch_sites]) / len(launch_sites)],
    zoom_start=5,
)

# Add a blue circle and a label for each launch site
for site in launch_sites:
    coordinates = (site["lat"], site["long"])
    site_name = site["name"]

    # Create a blue circle marker
    circle = folium.Circle(
        coordinates, radius=1000, color='#d35400', fill=True
    ).add_child(folium.Popup(site_name))
    site_map.add_child(circle)

    # Create a marker with a label
    marker = folium.map.Marker(
        coordinates,
        icon=DivIcon(
            icon_size=(20, 20),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 12px; color:#d35400;"><b>{site_name}</b></div>',
        ),
    )
    site_map.add_child(marker)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_662f0f127ffadebef81660a8312f649f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_662f0f127ffadebef81660a8312f649f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_662f0f127ffadebef81660a8312f649f = L.map(
#                 &quot;map_662f0f127ffadebef81660a8312f649f&quot;,
#                 {
#                     center: [30.082897, -90.602954],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8179099ce9f0d63fae9ba2dc6ad01bf9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_662f0f127ffadebef81660a8312f649f);
#
#
#             var circle_80bad203e6daff391bea59cb43a5160c = L.circle(
#                 [28.562302, -80.577356],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_662f0f127ffadebef81660a8312f649f);
#
#
#         var popup_e3013b935161eea544f4b710c0712cda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_95f9cad20875f53e91caa345649fa568 = $(`&lt;div id=&quot;html_95f9cad20875f53e91caa345649fa568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_e3013b935161eea544f4b710c0712cda.setContent(html_95f9cad20875f53e91caa345649fa568);
#
#
#         circle_80bad203e6daff391bea59cb43a5160c.bindPopup(popup_e3013b935161eea544f4b710c0712cda)
#         ;
#
#
#
#
#             var marker_1cc7ef312b7f12d025d9aae3abc9e1a2 = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(map_662f0f127ffadebef81660a8312f649f);
#
#
#             var div_icon_dc5c66fb3d46e2f04e80c3446a4fa706 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_1cc7ef312b7f12d025d9aae3abc9e1a2.setIcon(div_icon_dc5c66fb3d46e2f04e80c3446a4fa706);
#
#
#             var circle_322df95ca5f53992a1aae9dafa949f12 = L.circle(
#                 [28.563197, -80.57682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_662f0f127ffadebef81660a8312f649f);
#
#
#         var popup_5bed61f706359c92be1586099f1e7908 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_358604d7e668bd983bfef3f797cf2a5b = $(`&lt;div id=&quot;html_358604d7e668bd983bfef3f797cf2a5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_5bed61f706359c92be1586099f1e7908.setContent(html_358604d7e668bd983bfef3f797cf2a5b);
#
#
#         circle_322df95ca5f53992a1aae9dafa949f12.bindPopup(popup_5bed61f706359c92be1586099f1e7908)
#         ;
#
#
#
#
#             var marker_010669144e553c739fefd2746cc106ee = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(map_662f0f127ffadebef81660a8312f649f);
#
#
#             var div_icon_842619936dafc372d87a485ee58b929f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_010669144e553c739fefd2746cc106ee.setIcon(div_icon_842619936dafc372d87a485ee58b929f);
#
#
#             var circle_5cbb8905c18f7d4e4b7c4b9cd5539341 = L.circle(
#                 [28.573255, -80.646895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot

# %%
import folium
from folium import DivIcon
import pandas as pd



# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[launch_sites_df["Lat"].mean(), launch_sites_df["Long"].mean()],
    zoom_start=5,
)

# Add a blue circle and a label for each launch site
for _, row in launch_sites_df.iterrows():
    coordinates = (row["Lat"], row["Long"])
    site_name = row["Launch Site"]

    # Create a blue circle marker
    circle = folium.Circle(
        coordinates, radius=1000, color='#d35400', fill=True
    ).add_child(folium.Popup(site_name))
    site_map.add_child(circle)

    # Create a marker with a label
    marker = folium.map.Marker(
        coordinates,
        icon=DivIcon(
            icon_size=(20, 20),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 12px; color:#d35400;"><b>{site_name}</b></div>',
        ),
    )
    site_map.add_child(marker)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d37c0a3ad56e2faf13705762eeec4df4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d37c0a3ad56e2faf13705762eeec4df4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d37c0a3ad56e2faf13705762eeec4df4 = L.map(
#                 &quot;map_d37c0a3ad56e2faf13705762eeec4df4&quot;,
#                 {
#                     center: [30.08289697, -90.602954325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8b1eca9e981d29cc7e9e577df0a4b06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d37c0a3ad56e2faf13705762eeec4df4);
#
#
#             var circle_e722c93fe0e97d62adca63712d340c5c = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d37c0a3ad56e2faf13705762eeec4df4);
#
#
#         var popup_d4c4b5af046827af9de8de67865b3851 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b6ddcf9c231c7b8a4cf914cfd9ad7b41 = $(`&lt;div id=&quot;html_b6ddcf9c231c7b8a4cf914cfd9ad7b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#             popup_d4c4b5af046827af9de8de67865b3851.setContent(html_b6ddcf9c231c7b8a4cf914cfd9ad7b41);
#
#
#         circle_e722c93fe0e97d62adca63712d340c5c.bindPopup(popup_d4c4b5af046827af9de8de67865b3851)
#         ;
#
#
#
#
#             var marker_0fa1ce4a011ce9918e77085beda76288 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_d37c0a3ad56e2faf13705762eeec4df4);
#
#
#             var div_icon_976382d7cbfcf40bde38b8b1308165cd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_0fa1ce4a011ce9918e77085beda76288.setIcon(div_icon_976382d7cbfcf40bde38b8b1308165cd);
#
#
#             var circle_6ba73e9d4a4ad3fb8578076e6010da81 = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d37c0a3ad56e2faf13705762eeec4df4);
#
#
#         var popup_436c3c32badb4e98c8ef0b4264514fc4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ee756d0fa7f715a74e97959c013f432 = $(`&lt;div id=&quot;html_3ee756d0fa7f715a74e97959c013f432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#             popup_436c3c32badb4e98c8ef0b4264514fc4.setContent(html_3ee756d0fa7f715a74e97959c013f432);
#
#
#         circle_6ba73e9d4a4ad3fb8578076e6010da81.bindPopup(popup_436c3c32badb4e98c8ef0b4264514fc4)
#         ;
#
#
#
#
#             var marker_78c50f783101fb8b7e22f1b8cd175356 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_d37c0a3ad56e2faf13705762eeec4df4);
#
#
#             var div_icon_eb6e9617275aab5ea4813e888a92f7cd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_78c50f783101fb8b7e22f1b8cd175356.setIcon(div_icon_eb6e9617275aab5ea4813e888a92f7cd);
#
#
#             var circle_d459465ab02087e1aaa7c4ed59d51c5f = L.circle(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;,

# %%
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
import folium
from folium import DivIcon
import pandas as pd

# Example of spacex_df, replace it with your actual dataset
spacex_df = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'CCAFS SLC-40', 'KSC LC-39A', 'VAFB SLC-4E', 'CCAFS LC-40', 'KSC LC-39A'],
    'Lat': [28.562302, 28.563197, 28.573255, 34.632834, 28.562302, 28.573255],
    'Long': [-80.577356, -80.576820, -80.646895, -120.610745, -80.577356, -80.646895],
    'class': [1, 0, 1, 1, 1, 0]  # 1 for success, 0 for failure
})

# Group by Launch Site and calculate success rate
launch_outcomes = spacex_df.groupby('Launch Site')['class'].mean().reset_index()
launch_outcomes['color'] = launch_outcomes['class'].apply(lambda x: 'green' if x >= 0.75 else 'orange' if x >= 0.5 else 'red')

# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[spacex_df["Lat"].mean(), spacex_df["Long"].mean()],
    zoom_start=5,
)

# Add markers for each launch site, with color based on success rate
for _, row in launch_outcomes.iterrows():
    site_name = row['Launch Site']
    success_rate = row['class']
    color = row['color']
    
    # Get the coordinates for the launch site from spacex_df
    site_coords = spacex_df[spacex_df['Launch Site'] == site_name][['Lat', 'Long']].iloc[0]
    coordinates = (site_coords['Lat'], site_coords['Long'])

    # Create a marker with success/failure color and label
    marker = folium.map.Marker(
        coordinates,
        icon=DivIcon(
            icon_size=(20, 20),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 12px; color:{color};"><b>{site_name}</b><br>Success Rate: {success_rate*100:.2f}%</div>',
        ),
    )
    site_map.add_child(marker)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6ffc92bbea40987a89dfcbbc01ba5a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6ffc92bbea40987a89dfcbbc01ba5a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6ffc92bbea40987a89dfcbbc01ba5a4 = L.map(
#                 &quot;map_a6ffc92bbea40987a89dfcbbc01ba5a4&quot;,
#                 {
#                     center: [29.577857499999997, -87.27267783333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dadc96fa6ab8687e2694709c300815b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6ffc92bbea40987a89dfcbbc01ba5a4);
#
#
#             var marker_acc9465d6e1318ae7cd58051cd01fc64 = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(map_a6ffc92bbea40987a89dfcbbc01ba5a4);
#
#
#             var div_icon_9f6ca559ee3b69b89566c59a150242ac = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:green;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003cbr\u003eSuccess Rate: 100.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_acc9465d6e1318ae7cd58051cd01fc64.setIcon(div_icon_9f6ca559ee3b69b89566c59a150242ac);
#
#
#             var marker_f892537a9e8f976000016862a698c699 = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(map_a6ffc92bbea40987a89dfcbbc01ba5a4);
#
#
#             var div_icon_07382910745b208df1c229ac3442c19e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:red;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003cbr\u003eSuccess Rate: 0.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_f892537a9e8f976000016862a698c699.setIcon(div_icon_07382910745b208df1c229ac3442c19e);
#
#
#             var marker_29418c345ceb2aa305b3a9585a797abe = L.marker(
#                 [28.573255, -80.646895],
#                 {}
#             ).addTo(map_a6ffc92bbea40987a89dfcbbc01ba5a4);
#
#
#             var div_icon_0a97a3ae8510a6a4d206f1d17cd31801 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:orange;\&quot;\u003e\u003cb\u003eKSC LC-39A\u003c/b\u003e\u003cbr\u003eSuccess Rate: 50.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_29418c345ceb2aa305b3a9585a797abe.setIcon(div_icon_0a97a3ae8510a6a4d206f1d17cd31801);
#
#
#             var marker_a16eb35e59ec3c5bb9a32c0eb2156859 = L.marker(
#                 [34.632834, -120.610745],
#                 {}
#             ).addTo(map_a6ffc92bbea40987a89dfcbbc01ba5a4);
#
#
#             var div_icon_4c743c2c51622cb776f408fcd5f9de8f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:green;\&quot;\u003e\u003cb\u003eVAFB SLC-4E\u003c/b\u003e\u003cbr\u003eSuccess Rate: 100.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_a16eb35e59ec3c5bb9a32c0eb2156859.setIcon(div_icon_4c743c2c51622cb776f408fcd5f9de8f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.plugins import MarkerCluster

# Assuming spacex_df is your dataset and it already has the columns 'Launch Site', 'Lat', 'Long', and 'class'
# Example spacex_df
spacex_df = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'CCAFS SLC-40', 'KSC LC-39A', 'VAFB SLC-4E', 'CCAFS LC-40', 'KSC LC-39A'],
    'Lat': [28.562302, 28.563197, 28.573255, 34.632834, 28.562302, 28.573255],
    'Long': [-80.577356, -80.576820, -80.646895, -120.610745, -80.577356, -80.646895],
    'class': [1, 0, 1, 1, 1, 0]  # 1 for success, 0 for failure
})

# Create a new column `marker_color` based on the success/failure (class) column
spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: 'green' if x == 1 else 'red')

# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[spacex_df["Lat"].mean(), spacex_df["Long"].mean()],
    zoom_start=5,
)

# Create a MarkerCluster object
marker_cluster = MarkerCluster()

# For each row in spacex_df, create a Marker and add it to the MarkerCluster
for index, row in spacex_df.iterrows():
    coordinates = (row['Lat'], row['Long'])
    marker_color = row['marker_color']
    
    # Create a marker for each launch record
    marker = folium.Marker(
        location=coordinates,
        icon=folium.Icon(color=marker_color, icon='info-sign')  # Use green for success, red for failure
    )
    
    # Add the marker to the marker cluster
    marker_cluster.add_child(marker)

# Add the marker cluster to the map
site_map.add_child(marker_cluster)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91aead35cfafdde61c3a0f0288680ac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91aead35cfafdde61c3a0f0288680ac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91aead35cfafdde61c3a0f0288680ac8 = L.map(
#                 &quot;map_91aead35cfafdde61c3a0f0288680ac8&quot;,
#                 {
#                     center: [29.577857499999997, -87.27267783333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e071a0a18b41e92e8b390d9b66d85663 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91aead35cfafdde61c3a0f0288680ac8);
#
#
#             var marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898 = L.markerClusterGroup(
#                 {}
#             );
#             map_91aead35cfafdde61c3a0f0288680ac8.addLayer(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var marker_27866a73aea3f2fef347dc20e61a2c61 = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var icon_e8851dc7ae59a471e324ebe6fbbc0e37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27866a73aea3f2fef347dc20e61a2c61.setIcon(icon_e8851dc7ae59a471e324ebe6fbbc0e37);
#
#
#             var marker_7bd6846d93e1f80a5c976f4bd944af93 = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var icon_75abd902892098f5f9474c978055d23d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7bd6846d93e1f80a5c976f4bd944af93.setIcon(icon_75abd902892098f5f9474c978055d23d);
#
#
#             var marker_28ffe72fcebf597940cda2ae47e7ff62 = L.marker(
#                 [28.573255, -80.646895],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var icon_4dc50b71430d25df276980ddf93d3df0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28ffe72fcebf597940cda2ae47e7ff62.setIcon(icon_4dc50b71430d25df276980ddf93d3df0);
#
#
#             var marker_93224112a4ce1c9a49eef5373faf4bda = L.marker(
#                 [34.632834, -120.610745],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var icon_c6e312f2dba52d4a6b2e1dd7c6f0a2c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93224112a4ce1c9a49eef5373faf4bda.setIcon(icon_c6e312f2dba52d4a6b2e1dd7c6f0a2c9);
#
#
#             var marker_d7cfd6a76f101669193ca2d1ce8d4d3f = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);
#
#
#             var icon_28cf51c89123b04871096ecc9625d073 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7cfd6a76f101669193ca2d1ce8d4d3f.setIcon(icon_28cf51c89123b04871096ecc9625d073);
#
#
#             var marker_9e281638b9c74af935b52b9bbe8af013 = L.marker(
#                 [28.573255, -80.646895],
#                 {}
#             ).addTo(marker_cluster_ebdfd73ee55e5800b83af40bdd1dc898);

# %%
import folium
from folium import DivIcon
from folium.plugins import MarkerCluster
import pandas as pd

# Example of spacex_df, replace it with your actual dataset
spacex_df = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'CCAFS SLC-40', 'KSC LC-39A', 'VAFB SLC-4E', 'CCAFS LC-40', 'KSC LC-39A'],
    'Lat': [28.562302, 28.563197, 28.573255, 34.632834, 28.562302, 28.573255],
    'Long': [-80.577356, -80.576820, -80.646895, -120.610745, -80.577356, -80.646895],
    'class': [1, 0, 1, 1, 1, 0]  # 1 for success, 0 for failure
})

# Group by Launch Site and calculate success rate
launch_outcomes = spacex_df.groupby('Launch Site')['class'].mean().reset_index()
launch_outcomes['color'] = launch_outcomes['class'].apply(lambda x: 'green' if x >= 0.75 else 'orange' if x >= 0.5 else 'red')

# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[spacex_df["Lat"].mean(), spacex_df["Long"].mean()],
    zoom_start=5,
)

# Create a MarkerCluster object
marker_cluster = MarkerCluster()

# Add markers for each launch site, with color based on success rate
for _, row in launch_outcomes.iterrows():
    site_name = row['Launch Site']
    success_rate = row['class']
    color = row['color']
    
    # Get the coordinates for the launch site from spacex_df
    site_coords = spacex_df[spacex_df['Launch Site'] == site_name][['Lat', 'Long']].iloc[0]
    coordinates = (site_coords['Lat'], site_coords['Long'])

    # Create a marker with success/failure color and label
    marker = folium.map.Marker(
        coordinates,
        icon=DivIcon(
            icon_size=(20, 20),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 12px; color:{color};"><b>{site_name}</b><br>Success Rate: {success_rate*100:.2f}%</div>',
        ),
    )
    
    # Add marker to the MarkerCluster
    marker_cluster.add_child(marker)

# Add the MarkerCluster to the map
site_map.add_child(marker_cluster)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ceb07bd3bde01b8d729854f2af019e63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ceb07bd3bde01b8d729854f2af019e63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ceb07bd3bde01b8d729854f2af019e63 = L.map(
#                 &quot;map_ceb07bd3bde01b8d729854f2af019e63&quot;,
#                 {
#                     center: [29.577857499999997, -87.27267783333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddb2e7cec1489571a5322408c1df3bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ceb07bd3bde01b8d729854f2af019e63);
#
#
#             var marker_cluster_acc2a1e0cf51756d3d08edda862d66d2 = L.markerClusterGroup(
#                 {}
#             );
#             map_ceb07bd3bde01b8d729854f2af019e63.addLayer(marker_cluster_acc2a1e0cf51756d3d08edda862d66d2);
#
#
#             var marker_a90f2411b9a71380228819f3c9f0354c = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(marker_cluster_acc2a1e0cf51756d3d08edda862d66d2);
#
#
#             var div_icon_79dd8d5bd27889a731d2a20aa95ca016 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:green;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003cbr\u003eSuccess Rate: 100.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_a90f2411b9a71380228819f3c9f0354c.setIcon(div_icon_79dd8d5bd27889a731d2a20aa95ca016);
#
#
#             var marker_4ecab53be4b6acedb5dd3266922bd190 = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(marker_cluster_acc2a1e0cf51756d3d08edda862d66d2);
#
#
#             var div_icon_e2b4b37dcfb4f867c4398dd86609f915 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:red;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003cbr\u003eSuccess Rate: 0.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_4ecab53be4b6acedb5dd3266922bd190.setIcon(div_icon_e2b4b37dcfb4f867c4398dd86609f915);
#
#
#             var marker_8b0c714e05a974a4ef8088be8d121754 = L.marker(
#                 [28.573255, -80.646895],
#                 {}
#             ).addTo(marker_cluster_acc2a1e0cf51756d3d08edda862d66d2);
#
#
#             var div_icon_c00e3c9f8944e24cbb32a1c6d7e3b7bd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:orange;\&quot;\u003e\u003cb\u003eKSC LC-39A\u003c/b\u003e\u003cbr\u003eSuccess Rate: 50.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_8b0c714e05a974a4ef8088be8d121754.setIcon(div_icon_c00e3c9f8944e24cbb32a1c6d7e3b7bd);
#
#
#             var marker_6444a054f780576e8d3310136e5ffd6c = L.marker(
#                 [34.632834, -120.610745],
#                 {}
#             ).addTo(marker_cluster_acc2a1e0cf51756d3d08edda862d66d2);
#
#
#             var div_icon_b53343640fc6335caab316410fefb3dc = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:green;\&quot;\u003e\u003cb\u003eVAFB SLC-4E\u003c/b\u003e\u003cbr\u003eSuccess Rate: 100.00%\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_6444a054f780576e8d3310136e5ffd6c.setIcon(div_icon_b53343640fc6335caab316410fefb3dc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium import DivIcon
from folium.plugins import MarkerCluster
import pandas as pd

# Example of spacex_df, replace it with your actual dataset
spacex_df = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'CCAFS SLC-40', 'KSC LC-39A', 'VAFB SLC-4E', 'CCAFS LC-40', 'KSC LC-39A'],
    'Lat': [28.562302, 28.563197, 28.573255, 34.632834, 28.562302, 28.573255],
    'Long': [-80.577356, -80.576820, -80.646895, -120.610745, -80.577356, -80.646895],
    'class': [1, 0, 1, 1, 1, 0]  # 1 for success, 0 for failure
})

# Group by Launch Site and calculate success rate
launch_outcomes = spacex_df.groupby('Launch Site')['class'].mean().reset_index()
launch_outcomes['color'] = launch_outcomes['class'].apply(lambda x: 'green' if x >= 0.75 else 'orange' if x >= 0.5 else 'red')

# Create a map centered at the average latitude and longitude of the launch sites
site_map = folium.Map(
    location=[spacex_df["Lat"].mean(), spacex_df["Long"].mean()],
    zoom_start=5,
)

# Create a MarkerCluster object
marker_cluster = MarkerCluster()

# Add markers for each launch site, with color based on success rate
for _, row in launch_outcomes.iterrows():
    site_name = row['Launch Site']
    success_rate = row['class']
    color = row['color']
    
    # Get the coordinates for the launch site from spacex_df
    site_coords = spacex_df[spacex_df['Launch Site'] == site_name][['Lat', 'Long']].iloc[0]
    coordinates = (site_coords['Lat'], site_coords['Long'])

    # Create a colored marker based on success/failure
    marker = folium.Marker(
        coordinates,
        icon=folium.Icon(
            color=color,  # green for success, red for failure
            icon='info-sign',
            prefix='fa'
        ),
        popup=f'{site_name}<br>Success Rate: {success_rate*100:.2f}%',
    )

    # Add marker to the MarkerCluster
    marker_cluster.add_child(marker)

# Add the MarkerCluster to the map
site_map.add_child(marker_cluster)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3569502c0adff608d01ce2c990490f25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3569502c0adff608d01ce2c990490f25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3569502c0adff608d01ce2c990490f25 = L.map(
#                 &quot;map_3569502c0adff608d01ce2c990490f25&quot;,
#                 {
#                     center: [29.577857499999997, -87.27267783333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_010e646a4a246946f58ba8022330ac72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3569502c0adff608d01ce2c990490f25);
#
#
#             var marker_cluster_04f02f0e091d8bd71743c2da3b828bfa = L.markerClusterGroup(
#                 {}
#             );
#             map_3569502c0adff608d01ce2c990490f25.addLayer(marker_cluster_04f02f0e091d8bd71743c2da3b828bfa);
#
#
#             var marker_8c22a728064670fd7b1ded2b27f5c5ed = L.marker(
#                 [28.562302, -80.577356],
#                 {}
#             ).addTo(marker_cluster_04f02f0e091d8bd71743c2da3b828bfa);
#
#
#             var icon_85108cd220340379c87afda48645e721 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8c22a728064670fd7b1ded2b27f5c5ed.setIcon(icon_85108cd220340379c87afda48645e721);
#
#
#         var popup_eaeb05d96bf392798016c2380c6c5ed0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_72f941bdcdb9cac6c0f648ca66acafb3 = $(`&lt;div id=&quot;html_72f941bdcdb9cac6c0f648ca66acafb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;br&gt;Success Rate: 100.00%&lt;/div&gt;`)[0];
#             popup_eaeb05d96bf392798016c2380c6c5ed0.setContent(html_72f941bdcdb9cac6c0f648ca66acafb3);
#
#
#         marker_8c22a728064670fd7b1ded2b27f5c5ed.bindPopup(popup_eaeb05d96bf392798016c2380c6c5ed0)
#         ;
#
#
#
#
#             var marker_05099f7cd1132a369beebb53186b5380 = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(marker_cluster_04f02f0e091d8bd71743c2da3b828bfa);
#
#
#             var icon_47ebf74e070c6060e036c5d8c2463c87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_05099f7cd1132a369beebb53186b5380.setIcon(icon_47ebf74e070c6060e036c5d8c2463c87);
#
#
#         var popup_dd37b523f44760055020deca2250a22f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5fb950cf91e4d12ff3f563c47407a94d = $(`&lt;div id=&quot;html_5fb950cf91e4d12ff3f563c47407a94d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;br&gt;Success Rate: 0.00%&lt;/div&gt;`)[0];
#             popup_dd37b523f44760055020deca2250a22f.setContent(html_5fb950cf91e4d12ff3f563c47407a94d);
#
#
#         marker_05099f7cd1132a369beebb53186b5380.bindPopup(popup_dd37b523f44760055020deca2250a22f)
#         ;
#
#
#
#
#             var marker_efeaec986e0520ce50001ead37094298 = L.marker(
#                 [28.573255, -80.646895],
#                 {}
#             ).addTo(marker_cluster_04f02f0e091d8bd71743c2da3b828bfa);
#
#
#             var icon_a1d31a7cb230e798a60a4082b24dc483 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_efeaec986e0520ce50001ead37094298.setIcon(icon_a1d31a7cb230e798a60a4082b24dc483);
#
#
#         var popup_dc154656558e4fb3195f2af48d83ab42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a04c8baa1beb8cab739ac50b62d709c1 = $(`&lt;div id=&quot;html_a04c8baa1beb8cab739ac50b62d709c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;br&gt;Success Rate: 50.00%&lt;/div&gt;`)[0];
#             popup_dc154656558e4f
